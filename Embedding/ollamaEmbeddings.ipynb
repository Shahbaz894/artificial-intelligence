# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings=(
    OllamaEmbeddings(model='gemma:2b') #by default it used lama2
)

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embeddings.embed_documents(
    [
    "In recent years, the field of AI has seen a rapid growth in the size and capabilities of Large Language Model",
    "These models have demonstrated remarkable performance in a wide range of natural language processing tasks"
   
    
    
])

# %%
r1
# Out:
# [[0.09573014080524445,
#   -2.773517370223999,
#   -1.7763110399246216,
#   1.4936511516571045,
#   -0.40347564220428467,
#   2.4855453968048096,
#   1.1199736595153809,
#   -1.5977299213409424,
#   -1.885491967201233,
#   -0.5290613174438477,
#   0.2244623601436615,
#   -0.6618852019309998,
#   -0.22869117558002472,
#   -0.47440648078918457,
#   -1.0284277200698853,
#   0.9979480504989624,
#   8.184863090515137,
#   1.5681754350662231,
#   0.6345311403274536,
#   -0.7601317167282104,
#   2.1619184017181396,
#   -0.4141770303249359,
#   -0.7296042442321777,
#   -0.8228030204772949,
#   0.35767170786857605,
#   1.4170408248901367,
#   -0.5968053936958313,
#   -0.21638798713684082,
#   0.9705538153648376,
#   -1.3837907314300537,
#   -0.9805833697319031,
#   -0.7980904579162598,
#   -1.0027685165405273,
#   -0.8006207346916199,
#   -1.6430017948150635,
#   -2.531630039215088,
#   -0.8824214339256287,
#   1.05941903591156,
#   -0.4290043115615845,
#   -2.8918089866638184,
# ...

# %%
print(len(r1[0]))
# Out:
# 2048
